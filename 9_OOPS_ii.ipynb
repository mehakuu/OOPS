# %%
class employee:
    company="Google"
    def getsalary(self):
        print(f"Salary of the employee working in {self.company} is {self.salary}")

# %%
#creating a object
pardeep = employee()
#instance attribute
pardeep.salary = 100
pardeep.getsalary()
# Out:
# Salary of the employee working in Google is 100

# %%
employee.getsalary(pardeep)
# Out:
# Salary of the employee working in Google is 100

# %%
emp="Pardeep"
salary= 100
print(f"Name of the emp is {emp} and salary = {salary}")
# Out:
# Name of the emp is Pardeep and salary = 100

# %%
class employee:
    company="Google"
    def getsalary():
        print(f"Salary of the employee working in {self.company} is {self.salary}")

# %%
#creating a object
pardeep = employee()
#instance attribute
pardeep.salary = 100
pardeep.getsalary() 
#employee.getsalary(pardeep)
#to remove this error u have to add self while defining a function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e09ac1cdcada> in <module>
#       3 #instance attribute
#       4 pardeep.salary = 100
# ----> 5 pardeep.getsalary()
#       6 #employee.getsalary(pardeep)
#       7 #to remove this error u have to add self while defining a function
#
# TypeError: getsalary() takes 0 positional arguments but 1 was given

# %%
class employee:
    company="Google"
    @staticmethod
    def time():
        print("the time is 4 PM ")
#if u dont want to use self then make this function as static

# %%
#creating a object
pardeep = employee()
pardeep.time()
# Out:
# the time is 4 PM

# %%
class employee:
    company="Google"
    def __init__(self):
        print("employee is created")
    @staticmethod
    def time():
        print("the time is 4 PM ")
#if u dont want to use self then make this function as static 
# __init__ will be always called when u will create a object of the class

# %%
#creating a object
pardeep = employee()
pardeep.time()
# Out:
# employee is created
# the time is 4 PM

# %%
class Employee:
    company = "Google"

    def __init__(self, name, salary, subunit):
        self.name = name
        self.salary = salary
        self.subunit = subunit
        print("Employee is created!") 

    def getDetails(self):
        print(f"The name of the employee is {self.name}")
        print(f"The salary of the employee is {self.salary}")
        print(f"The subunit of the employee is {self.subunit}")

# %%
pardeep = Employee("Pardeep",100, "facebook")
pardeep.getDetails()
# Out:
# Employee is created!
# The name of the employee is Pardeep
# The salary of the employee is 100
# The subunit of the employee is facebook
